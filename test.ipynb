# %% [markdown]
# # Storytelling Application using Hugging Face Pipelines
# **ISOM5240 Assignment** — Image → Caption → Story (≤100 words) → Audio
# Application for 3–10 year-old kids. Image file is read from the current working directory by filename.

# %%
# Install required packages (run once) - per assignment: transformers<5.0.0
# !pip install "transformers<5.0.0" torch pillow
# Out:
# Requirement already satisfied: transformers<5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (4.57.6)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.13/site-packages (11.1.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (2024.11.6)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<5.0.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0) (1.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0) (4.12.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->transformers<5.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->transformers<5.0.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests->transformers<5.0.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->transformers<5.0.0) (2025.8.3)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Storytelling Application using Hugging Face Pipelines (Notebook version)
# Imports
import numpy as np
from transformers import pipeline
from PIL import Image
from IPython.display import display, Audio

# %%
# --- Function definitions ---
# Stage 1: Image to Text (caption) - recommended model per assignment
def img2text(image_path):
    """Generate a descriptive caption from the uploaded image using BLIP."""
    pipe = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
    result = pipe(image_path)[0]["generated_text"]
    return result

# Stage 2: Text to Story - transform caption into a short narrative (max 100 words)
def text2story(prompt_text, max_words=100):
    """Generate a narrative of no more than 100 words for the story."""
    pipe = pipeline("text-generation", model="pranavpsv/genre-story-generator-v2")
    out = pipe(prompt_text, max_new_tokens=150)[0]["generated_text"]
    words = out.split()
    if len(words) > max_words:
        out = " ".join(words[:max_words])
    return out

# Stage 3: Text to Audio - convert story to speech for playback
def text2audio(text):
    """Convert the generated story into audio format (returns dict with 'audio', 'sampling_rate')."""
    pipe = pipeline("text-to-speech", model="Matthijs/mms-tts-eng")
    return pipe(text)

# %%
# --- Main: Image filename in current working directory ---
# Imports (required if this cell is run without running the Imports cell first)
from PIL import Image
import numpy as np
from IPython.display import display, Audio

# Set the image filename (file must be in the current working directory)
image_filename = "YoungBoy.jpg"   # Change this to your image filename

# Load and display the uploaded image
img = Image.open(image_filename).convert("RGB")
display(img)

# Stage 1: Image to Text (caption)
print("Stage 1: Image to Text (caption)...")
scenario = img2text(image_filename)
print("Caption:", scenario)

# Stage 2: Text to Story (narrative, no more than 100 words)
print("\nStage 2: Generating story...")
story = text2story(scenario)
print("Story:", story)
print(f"\nWord count: {len(story.split())}")

# Stage 3: Text to Audio
print("\nStage 3: Converting story to audio...")
audio_data = text2audio(story)

# Play audio in notebook (for 3–10 year-old kids)
audio_array = np.array(audio_data["audio"]).squeeze()
sample_rate = audio_data["sampling_rate"]
display(Audio(audio_array, rate=sample_rate))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 image_filename = "YoungBoy.jpg"   # Change this to your image filename
#       5 # Load and display the uploaded image
# ----> 6 img = Image.open(image_filename).convert("RGB")
#       7 display(img)
#       9 # Stage 1: Image to Text (caption)
#
# NameError: name 'Image' is not defined
